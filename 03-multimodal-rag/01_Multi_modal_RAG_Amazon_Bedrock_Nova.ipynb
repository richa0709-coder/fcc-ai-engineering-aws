# %% [markdown]
# <a href="https://colab.research.google.com/github/richa0709-coder/fcc-ai-engineering-aws/blob/main/03-multimodal-rag/01_Multi_modal_RAG_Amazon_Bedrock_Nova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4);
#            color: white;
#            padding: 20px;
#            border-radius: 10px;
#            text-align: center;
#            font-family: Arial, sans-serif;
#            text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#   Multimodal RAG with Amazon Bedrock, Amazon Nova and LangChain
# </h1>

# %% [markdown]
# This notebook demonstrates how to implement a multi-modal Retrieval-Augmented Generation (RAG) system using **Amazon Bedrock with Amazon Nova and LangChain**. Many documents contain a mixture of content types, including text and images. Traditional RAG applications often lose valuable information captured in images. With the emergence of Multimodal Large Language Models (MLLMs), we can now leverage both text and image data in our RAG systems.
#
# In this notebook, we'll explore one approach to multi-modal RAG (`Option 1`):
#
# 1. Use multimodal embeddings (such as Amazon Titan) to embed both images and text
# 2. Retrieve relevant information using similarity search
# 3. Pass raw images and text chunks to a multimodal LLM for answer synthesis using Amazon Nova
#
# We'll use the following tools and technologies:
#
# - [LangChain](https://python.langchain.com/v0.2/docs/introduction/) to build a multimodal RAG system
# - [faiss](https://github.com/facebookresearch/faiss) for similarity search
# - [Amazon Nova](https://docs.aws.amazon.com/nova/latest/userguide/what-is-nova.html ) for answer synthesis
# - [Amazon Titan Multimodal Embeddings](https://docs.aws.amazon.com/bedrock/latest/userguide/titan-multiemb-models.html) for image embeddings
# - [Amazon Bedrock](https://aws.amazon.com/bedrock/) for accessing powerful AI models, like the ones above
# - [pymupdf](https://pymupdf.readthedocs.io/en/latest/) to parse images, text, and tables from documents (PDFs)
# - [boto3](https://boto3.amazonaws.com/v1/documentation/api/latest/index.html) for interacting with Amazon Bedrock
#
# This approach allows us to create a more comprehensive RAG system that can understand and utilize both textual and visual information from our documents.
#
# ## Prerequisites
#
# Before running this notebook, ensure you have the following packages and dependencies installed:
#
# - Python 3.10 or later
# - langchain
# - boto3
# - faiss
# - pymupdf
# - tabula
# - tesseract
# - requests
#
# Let's get started with building our multi-modal RAG system using Amazon Bedrock!

# %% [markdown]
# ![Multimodal RAG with Amazon Bedrock](https://github.com/richa0709-coder/fcc-ai-engineering-aws/blob/main/03-multimodal-rag/imgs/multimodal-rag1.png?raw=1)

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#    Importing the libs
# </h2>

# %% [markdown]
# Make sure you have installed all the required libraries to run this notebook
#
# ```bash
# cd 03-multimodal-rag
# pip install -r requirements.txt
#
# ```

# %%
# !pip install -r requirements.txt
# Core dependencies for Multimodal RAG with Amazon Bedrock Nova
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 82.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import boto3
import tabula
import faiss
import json
import base64
import pymupdf
import requests
import os
import logging
import numpy as np
import warnings
from tqdm import tqdm
from botocore.exceptions import ClientError
from langchain_text_splitters import RecursiveCharacterTextSplitter
from IPython import display

logger = logging.getLogger(__name__)
logger.setLevel(logging.ERROR)

warnings.filterwarnings("ignore")

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#    Data Loading
# </h2>

# %%
# Downloading the dataset - URL of the "Attention Is All You Need" paper (Replace it with the URL of the PDF file/dataset you want to download)
url = "https://arxiv.org/pdf/1706.03762.pdf"

# Set the filename and filepath
filename = "attention_paper.pdf"
filepath = os.path.join("data", filename)

# Create the data directory if it doesn't exist
os.makedirs("data", exist_ok=True)

# Download the file
response = requests.get(url)
if response.status_code == 200:
    with open(filepath, 'wb') as file:
        file.write(response.content)
    print(f"File downloaded successfully: {filepath}")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File downloaded successfully: data/attention_paper.pdf

# %%
# Display the PDF file
display.IFrame(filepath, width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="data/attention_paper.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#    Data Extraction
# </h2>

# %%
# Create the directories
def create_directories(base_dir):
    directories = ["images", "text", "tables", "page_images"]
    for dir in directories:
        os.makedirs(os.path.join(base_dir, dir), exist_ok=True)

# Process tables
def process_tables(doc, page_num, base_dir, items):
    try:
        tables = tabula.read_pdf(filepath, pages=page_num + 1, multiple_tables=True)
        if not tables:
            return
        for table_idx, table in enumerate(tables):
            table_text = "\n".join([" | ".join(map(str, row)) for row in table.values])
            table_file_name = f"{base_dir}/tables/{os.path.basename(filepath)}_table_{page_num}_{table_idx}.txt"
            with open(table_file_name, 'w') as f:
                f.write(table_text)
            items.append({"page": page_num, "type": "table", "text": table_text, "path": table_file_name})
    except Exception as e:
        print(f"Error extracting tables from page {page_num}: {str(e)}")

# Process text chunks
def process_text_chunks(text, text_splitter, page_num, base_dir, items):
    chunks = text_splitter.split_text(text)
    for i, chunk in enumerate(chunks):
        text_file_name = f"{base_dir}/text/{os.path.basename(filepath)}_text_{page_num}_{i}.txt"
        with open(text_file_name, 'w') as f:
            f.write(chunk)
        items.append({"page": page_num, "type": "text", "text": chunk, "path": text_file_name})

# Process images
def process_images(page, page_num, base_dir, items):
    images = page.get_images()
    for idx, image in enumerate(images):
        xref = image[0]
        pix = pymupdf.Pixmap(doc, xref)
        image_name = f"{base_dir}/images/{os.path.basename(filepath)}_image_{page_num}_{idx}_{xref}.png"
        pix.save(image_name)
        with open(image_name, 'rb') as f:
            encoded_image = base64.b64encode(f.read()).decode('utf8')
        items.append({"page": page_num, "type": "image", "path": image_name, "image": encoded_image})

# Process page images
def process_page_images(page, page_num, base_dir, items):
    pix = page.get_pixmap()
    page_path = os.path.join(base_dir, f"page_images/page_{page_num:03d}.png")
    pix.save(page_path)
    with open(page_path, 'rb') as f:
        page_image = base64.b64encode(f.read()).decode('utf8')
    items.append({"page": page_num, "type": "page", "path": page_path, "image": page_image})

# %%
doc = pymupdf.open(filepath)
num_pages = len(doc)
base_dir = "data"

# Creating the directories
create_directories(base_dir)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=700, chunk_overlap=200, length_function=len)
items = []

# Process each page of the PDF
for page_num in tqdm(range(num_pages), desc="Processing PDF pages"):
    page = doc[page_num]
    text = page.get_text()
    process_tables(doc, page_num, base_dir, items)
    process_text_chunks(text, text_splitter, page_num, base_dir, items)
    process_images(page, page_num, base_dir, items)
    process_page_images(page, page_num, base_dir, items)
# Out:
# Processing PDF pages:   0%|          | 0/15 [00:00<?, ?it/s]WARNING:tabula.backend:Failed to import jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'
# WARNING:tabula.backend:Got stderr: Sep 12, 2025 5:04:00 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Sep 12, 2025 5:04:00 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Sep 12, 2025 5:04:00 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Sep 12, 2025 5:04:00 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Sep 12, 2025 5:04:00 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# ...

# %%
# Looking at the first text item
[i for i in items if i['type'] == 'text'][0]
# Out:
# {'page': 0,
#  'type': 'text',
#  'text': 'Provided proper attribution is provided, Google hereby grants permission to\nreproduce the tables and figures in this paper solely for use in journalistic or\nscholarly works.\nAttention Is All You Need\nAshish Vaswani∗\nGoogle Brain\navaswani@google.com\nNoam Shazeer∗\nGoogle Brain\nnoam@google.com\nNiki Parmar∗\nGoogle Research\nnikip@google.com\nJakob Uszkoreit∗\nGoogle Research\nusz@google.com\nLlion Jones∗\nGoogle Research\nllion@google.com\nAidan N. Gomez∗†\nUniversity of Toronto\naidan@cs.toronto.edu\nŁukasz Kaiser∗\nGoogle Brain\nlukaszkaiser@google.com\nIllia Polosukhin∗‡\nillia.polosukhin@gmail.com\nAbstract\nThe dominant sequence transduction models are based on complex recurrent or',
#  'path': 'data/text/attention_paper.pdf_text_0_0.txt'}

# %%
# Looking at the first table item
[i for i in items if i['type'] == 'table'][0]
# Out:
# {'page': 5,
#  'type': 'table',
#  'text': 'nan | nan | Operations | nan\nSelf-Attention | O(n2 · d) | O(1) | O(1)\nRecurrent | O(n · d2) | O(n) | O(n)\nConvolutional | O(k · n · d2) | O(1) | O(logk(n))\nSelf-Attention (restricted) | O(r · n · d) | O(1) | O(n/r)',
#  'path': 'data/tables/attention_paper.pdf_table_5_0.txt'}

# %%
# Looking at the first image item
[i for i in items if i['type'] == 'image'][0]
# Out:
# {'page': 2,
#  'type': 'image',
#  'path': 'data/images/attention_paper.pdf_image_2_0_128.png',
#  'image': '...'}

# %%
# Looking at the first page image
[i for i in items if i['type'] == 'page'][0]
# Out:
# {'page': 0,
#  'type': 'page',
#  'path': 'data/page_images/page_000.png',
#  'image': '...'}

# %%
from google.colab import userdata

# Access your first secret key
aws_access_key_id = userdata.get('aws_access_key_id')
#print(f"AWS Access Key ID: {aws_access_key_id}")

aws_secret_access_key = userdata.get('aws_secret_access_key')
#print(f"AWS Secret Access Key: {aws_secret_access_key}")
# Access another secret key (replace 'another_secret_key' with your secret name)
# another_secret_value = userdata.get('another_secret_key')
# print(f"Another Secret Value: {another_secret_value}")

# You can access as many secret keys as you have stored in Colab secrets

import os

# Set environment variables for AWS credentials
os.environ['AWS_ACCESS_KEY_ID'] = aws_access_key_id
os.environ['AWS_SECRET_ACCESS_KEY'] = aws_secret_access_key

print("AWS environment variables have been set.")
# Out:
# AWS environment variables have been set.

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#   Generating Multimodal Embeddings
# </h2>

# %%
# Generating Multimodal Embeddings using Amazon Titan Multimodal Embeddings model
def generate_multimodal_embeddings(prompt=None, image=None, output_embedding_length=384):
    """
    Invoke the Amazon Titan Multimodal Embeddings model using Amazon Bedrock runtime.

    Args:
        prompt (str): The text prompt to provide to the model.
        image (str): A base64-encoded image data.
    Returns:
        str: The model's response embedding.
    """
    if not prompt and not image:
        raise ValueError("Please provide either a text prompt, base64 image, or both as input")

    # Initialize the Amazon Bedrock runtime client
    client = boto3.client(service_name="bedrock-runtime",region_name="us-east-1")
    model_id = "amazon.titan-embed-image-v1"

    body = {"embeddingConfig": {"outputEmbeddingLength": output_embedding_length}}

    if prompt:
        body["inputText"] = prompt
    if image:
        body["inputImage"] = image

    try:
        response = client.invoke_model(
            modelId=model_id,
            body=json.dumps(body),
            accept="application/json",
            contentType="application/json"
        )

        # Process and return the response
        result = json.loads(response.get("body").read())
        return result.get("embedding")

    except ClientError as err:
        print(f"Couldn't invoke Titan embedding model. Error: {err.response['Error']['Message']}")
        return None

# %%
# Set embedding vector dimension
embedding_vector_dimension = 384

# Count the number of each type of item
item_counts = {
    'text': sum(1 for item in items if item['type'] == 'text'),
    'table': sum(1 for item in items if item['type'] == 'table'),
    'image': sum(1 for item in items if item['type'] == 'image'),
    'page': sum(1 for item in items if item['type'] == 'page')
}

# Initialize counters
counters = dict.fromkeys(item_counts.keys(), 0)

# Generate embeddings for all items
with tqdm(
    total=len(items),
    desc="Generating embeddings",
    bar_format=(
        "{l_bar}{bar}| {n_fmt}/{total_fmt} "
        "[{elapsed}<{remaining}, {rate_fmt}{postfix}]"
    )
) as pbar:

    for item in items:
        item_type = item['type']
        counters[item_type] += 1

        if item_type in ['text', 'table']:
            # For text or table, use the formatted text representation
            item['embedding'] = generate_multimodal_embeddings(prompt=item['text'],output_embedding_length=embedding_vector_dimension)
        else:
            # For images, use the base64-encoded image data
            item['embedding'] = generate_multimodal_embeddings(image=item['image'], output_embedding_length=embedding_vector_dimension)

        # Update the progress bar
        pbar.set_postfix_str(f"Text: {counters['text']}/{item_counts['text']}, Table: {counters['table']}/{item_counts['table']}, Image: {counters['image']}/{item_counts['image']}")
        pbar.update(1)
# Out:
# Generating embeddings: 100%|██████████| 108/108 [00:24<00:00,  4.33it/s, Text: 83/83, Table: 7/7, Image: 3/3]

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#   Creating Vector Database/Index
# </h2>

# %%
# All the embeddings
all_embeddings = np.array([item['embedding'] for item in items])

# Create FAISS Index
index = faiss.IndexFlatL2(embedding_vector_dimension)

# Clear any pre-existing index
index.reset()

# Add embeddings to the index
index.add(np.array(all_embeddings, dtype=np.float32))

# %%
from langchain_aws import ChatBedrock

# Generating RAG response with Amazon Nova
def invoke_nova_multimodal(prompt, matched_items):
    """
    Invoke the Amazon Nova model.
    """
    # Define your system prompt(s).
    system_msg = [
                        { "text": """You are a helpful assistant for question answering.
                                    The text context is relevant information retrieved.
                                    The provided image(s) are relevant information retrieved.
                                    Do not add any information that is not directly supported by the retrieved documents.
                                    When answering, cite the page numbers from the provided context where you found the information.
                                    Format citations like this: [Page X][Path Y].
                                    """} # Added instruction to cite page numbers
                ]

    # Define one or more messages using the "user" and "assistant" roles.
    message_content = []

    for item in matched_items:
        if item['type'] == 'text' or item['type'] == 'table':
            # Include page number in the context provided to the model
            message_content.append({"text": f"--- Content from Page {item['page']} and Path {item['path']} ---\n{item['text']}"})
        else:
            message_content.append({"image": {
                                                "format": "png",
                                                "source": {"bytes": item['image']},
                                            }
                                    })


    # Configure the inference parameters.
    inf_params = {"max_new_tokens": 300,
                "top_p": 0.9,
                "top_k": 20}

    # Construct the final prompt for the LLM, emphasizing not adding external information
    # You would then pass this context to your LLM (e.g., Amazon Nova)
    # The model expects a list of message dictionaries
    messages = [
        {"role": "user", "content": message_content},
        {"role": "user", "content": [{"text": prompt}]}, # Add the user's query as a text message
    ]

    native_request = {
        "messages": messages,
        "system": system_msg,
        "inferenceConfig": inf_params,
    }

    # Initialize the Amazon Bedrock runtime client
    model_id = "amazon.nova-pro-v1:0"
    client = ChatBedrock(model_id=model_id, region_name="us-east-1")

    # Invoke the model and extract the response body.
    response = client.invoke(json.dumps(native_request))
    model_response = response.content

    return model_response

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#   Test the RAG Pipeline
# </h2>

# %%
# Check the result (matched chunks)
print(result.flatten())
result.flatten()
# Out:
# [98 54 68 14 78]
# array([98, 54, 68, 14, 78])

# %%
from IPython.display import display, Image

# prompt: add code to retrieve page image for pages cited

def retrieve_page_images(pages_to_retrieve, base_dir="data"):
    """
    Retrieves and displays the image for the specified page numbers.

    Args:
        pages_to_retrieve (list): A list of page numbers (integers or strings) to retrieve.
        base_dir (str): The base directory where the page images are stored.
    """
    for page_num_str in list(set(pages_to_retrieve)): # Ensure unique pages and iterate
        try:
            page_num = int(page_num_str)
            # Page numbers are 0-indexed in pymupdf but 1-indexed in the citations, so we subtract 1
            image_path = os.path.join(base_dir, f"page_images/page_{page_num:03d}.png")
            print("image path", image_path)
            print(f"Retrieving image for page {page_num}...")
            display(Image(filename=image_path))
        except ValueError:
            print(f"Skipping invalid page number: {page_num_str}")
        except FileNotFoundError:
            print(f"Error: Image for page {page_num} not found at '{image_path}'.")
        except Exception as e:
            print(f"An error occurred while retrieving image for page {page_num}: {e}")

# Example usage after getting pages_cited from the RAG response:
#retrieve_page_images(pages_cited, base_dir="data")

# %% [markdown]
# <h2 style="background: linear-gradient(to right, #ff6b6b, #4ecdc4, #1e90ff);
#             color: white;
#             padding: 15px;
#             border-radius: 10px;
#             text-align: center;
#             font-family: 'Comic Sans MS', cursive, sans-serif;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.5);">
#   Your Turn: Test the RAG Pipeline
# </h2>

# %%
# List of queries (Replace with any query of your choice)
other_queries = ["How long were the base and big models trained?",
                 "Which optimizer was used when training the models?",
                 "What is the position-wise feed-forward neural network mentioned in the paper?",
                 "What is the BLEU score of the model in English to German translation (EN-DE)?",
                 "How is the scaled-dot-product attention is calculated?",
                 ]

# %%
# import pandas as pd
# from IPython.display import display # Ensure display is imported here

# # Create a list of dictionaries with simplified information for the table

# def displayAsTable(matched_items):
#   table_data = []
#   for item in matched_items:
#       item_info = {
#           "Page": item['page'],
#           "Type": item['type'],
#           "Content Preview": item['text'][:100] + "..." if item['type'] in ['text', 'table'] and isinstance(item['text'], str) and len(item['text']) > 100 else item['text'] if item['type'] in ['text', 'table'] else "N/A",
#           "Path": item['path'] if 'path' in item else "N/A"
#       }
#       table_data.append(item_info)
#   return table_data

# %%
from IPython.display import display # Ensure display is imported here
import pandas as pd
import re # Import the re module

query = other_queries[1] # Replace with any query from the list above

# Generate embeddings for the query
query_embedding = generate_multimodal_embeddings(prompt=query,output_embedding_length=embedding_vector_dimension)

# Search for the nearest neighbors in the vector database
distances, result = index.search(np.array(query_embedding, dtype=np.float32).reshape(1,-1), k=5)

# Retrieve the matched items and their original indices
matched_items = []
for original_index in result.flatten():
    item = items[original_index]
    matched_items.append({
        "original_index": original_index,
        **{k: v for k, v in item.items() if k != 'embedding'}
    })

#display matched_items
def displayAsTable(matched_items):
    table_data = []
    for item in matched_items:
        item_info = {
            "Original Index": item['original_index'],
            "Page": item['page'],
            "Type": item['type'],
            "Content Preview": item['text'][:100] + "..." if item['type'] in ['text', 'table'] and isinstance(item['text'], str) and len(item['text']) > 100 else item['text'] if item['type'] in ['text', 'table'] else "N/A",
            "Path": item['path'] if 'path' in item else "N/A"
        }
        table_data.append(item_info)
    return table_data

matched_items_df = pd.DataFrame(displayAsTable(matched_items))

# Display the DataFrame
display(matched_items_df)

# Generate RAG response with Amazon Nova
response = invoke_nova_multimodal(query, matched_items)

# Display the response
#display.Markdown(response)

print("Response\n", response)
#display.Markdown(response)

# Extract page numbers and paths cited in response
cited_references = []
# Updated regex to capture both page number and path
citation_matches = re.findall(r'\[Page (\d+)\]\[Path (.*?)\]', response)
for page, path in citation_matches:
    cited_references.append({"page": page, "path": path})

print(f"Cited references: {cited_references}")

# You can add more sophisticated parsing if the model's citation format is different

# print(f"Pages cited in response: {list(set(pages_cited))}") # Print unique pages

# retrieve_page_images(pages_cited)
# Assuming you want to retrieve images for the cited pages
cited_pages_only = [ref["page"] for ref in cited_references]
retrieve_page_images(cited_pages_only)
# Out:
#    Original Index  Page  Type  \
# 0              64     7  text
# 1              78     9  text
# 2              54     6  text
# 3              60     7  text
# 4              14     1  text
#
#                                      Content Preview  \
# 0  To evaluate the importance of different compon...
# 1  prisingly well, yielding better results than a...
# 2  We trained our models on one machine with 8 NV...
# 3  Label Smoothing\nDuring training, we employed ...
# 4  language modeling tasks [34].\nTo the best of ...
#
#                                          Path
# 0  data/text/attention_paper.pdf_text_7_6.txt
# 1  data/text/attention_paper.pdf_text_9_2.txt
# 2  data/text/attention_paper.pdf_text_6_5.txt
# 3  data/text/attention_paper.pdf_text_7_2.txt
# 4  data/text/attention_paper.pdf_text_1_7.txt
# Response
#  The Adam optimizer was used when training the models [Page 6][Path data/text/attention_paper.pdf_text_6_5.txt].
# ...

# %%
def read_cited_content(cited_path):
    """
    Reads and prints the text content of a file at the given path.

    Args:
        cited_path (str): The path to the cited file.
    """
    try:
        with open(cited_path, 'r') as f:
            cited_content = f.read()
            print(f"\n--- Content from Cited Path: {cited_path} ---\n{cited_content}\n------------------------------------------\n")
            return cited_content
    except FileNotFoundError:
        print(f"Error: Cited file not found at {cited_path}")
    except Exception as e:
        print(f"Error reading cited file {cited_path}: {e}")

# Example usage (you can replace this with a path from your cited_references)
# For example, if your cited_references list is not empty, you can use:
# if cited_references:
#     example_path = cited_references[0]['path']
#     read_cited_content(example_path)
# else:
#     print("No cited references found to read content.")

# %%
# prompt: generate code to highlight citation response in page image

def highlight_citations_on_page_image(image_path, cited_references, all_items):
    """
    Highlights the areas on the page image corresponding to the cited references.

    Args:
        image_path (str): The file path to the page image.
        cited_references (list): A list of dictionaries, where each dictionary
                                 contains 'page' (str) and 'path' (str) of the cited item.
        all_items (list): The complete list of items extracted from the document,
                          including their original page and path information.
    """
    try:
        doc = pymupdf.open(filepath) # Re-open the document

        # Find the corresponding PDF page for the image path
        page_match = re.search(r'page_(\d+)\.png$', image_path)
        pdf_page = None
        page_num = -1 # Initialize page_num outside the if block
        if page_match:
            page_num_str = page_match.group(1)
            page_num = int(page_num_str) # Page number from the image filename (0-indexed)
            if 0 <= page_num < len(doc):
                pdf_page = doc[page_num]
                print(f"Processing PDF page {page_num + 1} for highlighting.")
                print(f"PDF Page dimensions: width={pdf_page.rect.width}, height={pdf_page.rect.height}")
            else:
                print(f"Warning: Page number {page_num} extracted from image path is out of bounds.")
                doc.close()
                return
        else:
            print(f"Could not extract page number from image path: {image_path}")
            doc.close()
            return

        print("*******")
        print("page number",page_num)
        # We will draw directly on the PDF page and then get a new pixmap
        # This avoids issues with copying the standalone pixmap


        for ref in cited_references:
            cited_page_str = ref['page']
            cited_path = ref['path']
            print(f"Processing cited reference: Page={cited_page_str}, Path={cited_path}")
            chunk_text = read_cited_content(cited_path)
            print("-----------",chunk_text)
            try:
                cited_page_num = int(cited_page_str)
                # Check if the cited reference is on the current page image
                # Note: page_num is 0-indexed (from image filename), cited_page_num is 1-indexed (from regex)
                if cited_page_num != page_num:
                    continue # Skip if the citation is for a different page

                print(f"Attempting to highlight item from cited page {cited_page_num} with path: {cited_path}")

                # Find the item in the original items list based on path and page
                matching_items = [
                    item for item in all_items
                    if 'path' in item and item['path'] == cited_path and item['page'] == cited_page_num # Adjust for 0-indexed page in items
                ]

                if not matching_items:
                    print(f"Warning: Could not find item with path '{cited_path}' on page {cited_page_num} in original items.")
                    continue

                # Assuming there's at least one match, take the first one
                matched_item = matching_items[0]
                print(f"Found matching item: Type={matched_item['type']}, Page={matched_item['page']}, Path={matched_item['path']}")


                # Now, get the coordinates of the item on the original PDF page
                if matched_item['type'] == 'text' or matched_item['type'] == 'table':
                     # For text or tables, find text instances based on the content
                    search_text = matched_item['text'] # Use a portion of the text to search
                    text_instances = pdf_page.search_for(search_text)
                    found_chunk = pdf_page.search_for(chunk_text)
                    print("ffffffffffffff",found_chunk)
                    if not found_chunk:
                        print(f"Warning: Could not find text instance for highlighting on page {page_num + 1} for path '{cited_path}'.")
                        continue
                    else:
                        #draw rectangle for every chunk in found_chunk
                        for chunk in found_chunk:
                            pdf_page.draw_rect(chunk, color=(1, 0, 0), width=3) # Draw on PDF page, increased width
                            print("Drew red rectangle.")

                    # if text_instances:
                    #     # Assuming the first instance is the correct one
                    #     rect = text_instances[0]
                    #     print(f"Found text instance coordinates: {rect}")
                    #     # Draw red rectangle on the PDF page
                    #     pdf_page.draw_rect(rect, color=(1, 0, 0), width=3) # Draw on PDF page, increased width
                    #     print("Drew red rectangle.")
                    # else:
                    #     print(f"Warning: Could not find text instance for highlighting on page {page_num + 1} for path '{cited_path}'.")


                elif matched_item['type'] == 'image':
                    # For images, find the image location on the page
                    images = pdf_page.get_images(full=True)
                    found_image = False
                    for img_index, img_info in enumerate(images):
                         xref = img_info[0]
                         # Find the original item in 'items' that corresponds to this xref and page
                         original_image_item = next((item for item in all_items if item.get('type') == 'image' and item.get('page') == page_num and str(xref) in item.get('path', '')), None)

                         if original_image_item and original_image_item['path'] == cited_path:
                             # Get the image rectangle(s) on the PDF page
                             img_rects = pdf_page.get_image_rects(xref)
                             if img_rects:
                                 img_rect = img_rects[0] # Assuming one rect per image xref
                                 print(f"Found image instance coordinates: {img_rect}")
                                 # Draw blue rectangle on the PDF page
                                 pdf_page.draw_rect(img_rect, color=(0, 0, 1), width=3) # Draw on PDF page, increased width
                                 found_image = True
                                 print("Drew blue rectangle.")
                                 break # Assume we found the right image
                    if not found_image:
                         print(f"Warning: Could not find image instance for highlighting on page {page_num + 1} for path '{cited_path}'.")


            except ValueError:
                print(f"Skipping invalid cited page number: {cited_page_str}")
            except Exception as e:
                print(f"An error occurred while highlighting citation for path '{cited_path}': {e.with_traceback}")

        # Get a new pixmap of the page with the drawings
        highlighted_pix = pdf_page.get_pixmap()

        # Save the modified pixmap to a temporary file
        highlighted_image_path = image_path.replace(".png", "_highlighted.png")
        highlighted_pix.save(highlighted_image_path)

        # Display the highlighted image
        print(f"Displaying highlighted image for page {page_num + 1}:")
        display(Image(filename=highlighted_image_path))

        doc.close() # Close the document
        # highlighted_pix.close() # Removed incorrect close call


    except FileNotFoundError:
        print(f"Error: The page image file '{image_path}' was not found.")
    except Exception as e:
        print(f"An error occurred while processing the page image: {e}")
        # Remove the specific hint as it seems to be misleading
        # if 'Document' in str(e) and 'width' in str(e):
        #      print("Hint: The error 'Document' object has no attribute 'width' suggests an issue accessing width/height from the main PDF document object instead of a specific page or pixmap.")


# Example usage after getting cited_references from the RAG response:
# You need to call this for each cited page image you want to display and highlight.
# Iterate through the unique cited pages and find their corresponding image paths
# Assuming cited_references is a list of dictionaries with 'page' and 'path'

unique_cited_pages = list(set([ref["page"] for ref in cited_references]))

for page_num_str in unique_cited_pages:
    try:
        page_num = int(page_num_str)
        # Page numbers are 0-indexed in pymupdf but 1-indexed in the citations, so we subtract 1 for the file path
        image_path_for_page = os.path.join("data", f"page_images/page_{page_num:03d}.png")
        if os.path.exists(image_path_for_page):
             # Pass the list of all original items to the highlighting function
            highlight_citations_on_page_image(image_path_for_page, cited_references, items)
        else:
            print(f"Page image not found for page {page_num} at {image_path_for_page}")
    except ValueError:
        print(f"Skipping invalid page number in unique cited pages: {page_num_str}")
    except Exception as e:
        print(f"An error occurred while processing unique cited pages: {e}")
# Out:
# Processing PDF page 7 for highlighting.
# PDF Page dimensions: width=612.0, height=792.0
# *******
# page number 6
# Processing cited reference: Page=6, Path=data/text/attention_paper.pdf_text_6_5.txt
#
# --- Content from Cited Path: data/text/attention_paper.pdf_text_6_5.txt ---
# We trained our models on one machine with 8 NVIDIA P100 GPUs. For our base models using
# the hyperparameters described throughout the paper, each training step took about 0.4 seconds. We
# trained the base models for a total of 100,000 steps or 12 hours. For our big models,(described on the
# bottom line of table 3), step time was 1.0 seconds. The big models were trained for 300,000 steps
# (3.5 days).
# 5.3
# Optimizer
# We used the Adam optimizer [20] with β1 = 0.9, β2 = 0.98 and ϵ = 10−9. We varied the learning
# rate over the course of training, according to the formula:
# lrate = d−0.5
# model · min(step_num−0.5, step_num · warmup_steps−1.5)
# (3)
# ------------------------------------------
#
# ...

# %%
# ##formatted print of items

# for i, item in enumerate(items):
#     print(f"--- Item {i} ---")
#     for key, value in item.items():
#         if key == 'embedding':
#             print(f"{key}: [embedding data, shape: {np.array(value).shape}]")
#         elif isinstance(value, str) and len(value) > 200:
#             print(f"{key}: {value[:200]}...")
#         else:
#             print(f"{key}: {value}")
#     print("-" * (len(f"--- Item {i} ---")))

# %%
# #print items where type is table

# import numpy as np # Ensure numpy is imported for shape

# print("--- Table Items ---")
# for i, item in enumerate(items):
#     if item['type'] == 'table':
#         print(f"--- Item {i} ---")
#         for key, value in item.items():
#             if key == 'embedding':
#                 # Assuming 'embedding' is a list or numpy array
#                 print(f"{key}: [embedding data, shape: {np.array(value).shape}]")
#             elif isinstance(value, str) and len(value) > 200:
#                 print(f"{key}: {value[:200]}...")
#             else:
#                 print(f"{key}: {value}")
#         print("-" * (len(f"--- Item {i} ---")))
# print("--- End of Table Items ---")

# %%
# Out:
#    Page  Type                                    Content Preview  \
# 0     7  text  To evaluate the importance of different compon...
# 1     9  text  prisingly well, yielding better results than a...
# 2     6  text  We trained our models on one machine with 8 NV...
# 3     7  text  Label Smoothing\nDuring training, we employed ...
# 4     1  text  language modeling tasks [34].\nTo the best of ...
#
#                                          Path
# 0  data/text/attention_paper.pdf_text_7_6.txt
# 1  data/text/attention_paper.pdf_text_9_2.txt
# 2  data/text/attention_paper.pdf_text_6_5.txt
# 3  data/text/attention_paper.pdf_text_7_2.txt
# 4  data/text/attention_paper.pdf_text_1_7.txt

# %%
# import pandas as pd

# from IPython.display import display # Ensure display is imported here

# query = other_queries[1] # Replace with any query from the list above

# # Generate embeddings for the query
# query_embedding = generate_multimodal_embeddings(prompt=query,output_embedding_length=embedding_vector_dimension)

# # Search for the nearest neighbors in the vector database
# distances, result = index.search(np.array(query_embedding, dtype=np.float32).reshape(1,-1), k=5)

# # Define the displayAsTable function again or ensure it's available
# def displayAsTable(matched_items):
#     table_data = []
#     for item in matched_items:
#         item_info = {
#             "Original Index": item['original_index'],
#             "Page": item['page'],
#             "Type": item['type'],
#             "Content Preview": item['text'][:100] + "..." if item['type'] in ['text', 'table'] and isinstance(item['text'], str) and len(item['text']) > 100 else item['text'] if item['type'] in ['text', 'table'] else "N/A",
#             "Path": item['path'] if 'path' in item else "N/A"
#         }
#         table_data.append(item_info)
#     return table_data

# # Retrieve the matched items
# matched_items = []
# for original_index in result.flatten():
#     item = items[original_index]
#     matched_items.append({
#         "original_index": original_index,
#         **{k: v for k, v in item.items() if k != 'embedding'}
#     })

# #display matched_items
# matched_items_df = pd.DataFrame(displayAsTable(matched_items))

# # Display the DataFrame
# display(matched_items_df)

# # Generate RAG response with Amazon Nova
# response = invoke_nova_multimodal(query, matched_items)

# # Display the response
# #display.Markdown(response)

# print("Response\n", response)
# #display.Markdown(response)

# # Example: Simple parsing for [Page X] format
# pages_cited = []
# import re
# page_matches = re.findall(r'\[Page (\d+)\]', response)
# pages_cited.extend(page_matches)

# # You can add more sophisticated parsing if the model's citation format is different

# print(f"Pages cited in response: {list(set(pages_cited))}") # Print unique pages

# retrieve_page_images(pages_cited)
# Out:
#    Original Index  Page  Type  \
# 0              64     7  text
# 1              78     9  text
# 2              54     6  text
# 3              60     7  text
# 4              14     1  text
#
#                                      Content Preview  \
# 0  To evaluate the importance of different compon...
# 1  prisingly well, yielding better results than a...
# 2  We trained our models on one machine with 8 NV...
# 3  Label Smoothing\nDuring training, we employed ...
# 4  language modeling tasks [34].\nTo the best of ...
#
#                                          Path
# 0  data/text/attention_paper.pdf_text_7_6.txt
# 1  data/text/attention_paper.pdf_text_9_2.txt
# 2  data/text/attention_paper.pdf_text_6_5.txt
# 3  data/text/attention_paper.pdf_text_7_2.txt
# 4  data/text/attention_paper.pdf_text_1_7.txt
# Response
#  The Adam optimizer was used when training the models [Page 6].
#
# [Match:1]
# Pages cited in response: ['6']
# image path data/page_images/page_006.png
# ...

# %%
def read_cited_content(cited_path):
    """
    Reads and prints the text content of a file at the given path.

    Args:
        cited_path (str): The path to the cited file.
    """
    try:
        with open(cited_path, 'r') as f:
            cited_content = f.read()
            print(f"\n--- Content from Cited Path: {cited_path} ---\n{cited_content}\n------------------------------------------\n")
            return cited_content
    except FileNotFoundError:
        print(f"Error: Cited file not found at {cited_path}")
    except Exception as e:
        print(f"Error reading cited file {cited_path}: {e}")

# Example usage (you can replace this with a path from your cited_references)
# For example, if your cited_references list is not empty, you can use:
# if cited_references:
#     example_path = cited_references[0]['path']
#     read_cited_content(example_path)
# else:
#     print("No cited references found to read content.")

# %%
from IPython.display import display, Image
import fitz # PyMuPDF
import re
import os

def optimized_highlight_citations_on_page_image(image_path, cited_references, all_items):
    """
    Optimized version of the highlight function.
    Highlights the areas on the page image corresponding to the cited references.

    Args:
        image_path (str): The file path to the page image.
        cited_references (list): A list of dictionaries, where each dictionary
                                 contains 'page' (str) and 'path' (str) of the cited item.
        all_items (list): The complete list of items extracted from the document,
                          including their original page and path information.
    """
    try:
        doc = pymupdf.open(filepath) # Re-open the document

        # Find the corresponding PDF page for the image path
        page_match = re.search(r'page_(\d+)\.png$', image_path)
        pdf_page = None
        page_num = -1 # Initialize page_num outside the if block
        if page_match:
            page_num_str = page_match.group(1)
            page_num = int(page_num_str) # Page number from the image filename (0-indexed)
            if 0 <= page_num < len(doc):
                pdf_page = doc[page_num]
                print(f"Processing PDF page {page_num + 1} for highlighting.")
                print(f"PDF Page dimensions: width={pdf_page.rect.width}, height={pdf_page.rect.height}")
            else:
                print(f"Warning: Page number {page_num} extracted from image path is out of bounds.")
                doc.close()
                return
        else:
            print(f"Could not extract page number from image path: {image_path}")
            doc.close()
            return

        # Create a lookup structure for all_items by page and path
        item_lookup = {}
        for item in all_items:
             if 'path' in item:
                 # Use a tuple (page_num, path) as the key for easier lookup
                 item_lookup[(item['page'], item['path'])] = item

        # We will draw directly on the PDF page and then get a new pixmap
        # This avoids issues with copying the standalone pixmap


        for ref in cited_references:
            cited_page_str = ref['page']
            cited_path = ref['path']

            try:
                cited_page_num = int(cited_page_str)
                # Check if the cited reference is on the current page image
                # Note: page_num is 0-indexed (from image filename), cited_page_num is 1-indexed (from regex)
                if cited_page_num != page_num + 1:
                    continue # Skip if the citation is for a different page

                print(f"Attempting to highlight item from cited page {cited_page_num} with path: {cited_path}")

                # Use the lookup structure to find the matching item
                lookup_key = (cited_page_num - 1, cited_path) # Adjust cited_page_num to be 0-indexed for lookup
                matched_item = item_lookup.get(lookup_key)


                if not matched_item:
                    print(f"Warning: Could not find item with path '{cited_path}' on page {cited_page_num} in original items lookup.")
                    continue

                print(f"Found matching item: Type={matched_item['type']}, Page={matched_item['page']}, Path={matched_item['path']}")


                # Now, get the coordinates of the item on the original PDF page
                if matched_item['type'] == 'text' or matched_item['type'] == 'table':
                     # For text or tables, find text instances based on the content
                    search_text = matched_item['text'][:50] # Use a portion of the text to search
                    text_instances = pdf_page.search_for(search_text)

                    if text_instances:
                        # Assuming the first instance is the correct one
                        rect = text_instances[0]
                        print(f"Found text instance coordinates: {rect}")
                        # Draw red rectangle on the PDF page
                        pdf_page.draw_rect(rect, color=(1, 0, 0), width=3) # Draw on PDF page, increased width
                        print("Drew red rectangle.")
                    else:
                        print(f"Warning: Could not find text instance for highlighting on page {page_num + 1} for path '{cited_path}'.")


                elif matched_item['type'] == 'image':
                    # For images, find the image location on the page
                    images = pdf_page.get_images(full=True)
                    found_image = False
                    for img_index, img_info in enumerate(images):
                         xref = img_info[0]
                         # Find the original item in 'items' that corresponds to this xref and page
                         # Use the lookup structure here too for consistency, although the previous method might be fine
                         # We need to find the item in the original 'items' that corresponds to this xref and is on the current page_num
                         # The lookup structure is based on (page, path), so we need to find the path from xref

                         # A better approach for images might be to store the image rects during extraction
                         # For now, we'll stick to finding the xref on the pdf_page and getting its rects

                         img_paths_for_page = [item['path'] for item in all_items if item['type'] == 'image' and item['page'] == page_num]

                         # Need to find a way to map xref to path if not stored directly during extraction
                         # Assuming the path contains the xref as in the original extraction code
                         original_image_item = next((item for item in all_items if item.get('type') == 'image' and item.get('page') == page_num and str(xref) in item.get('path', '')), None)


                         if original_image_item and original_image_item['path'] == cited_path:
                             # Get the image rectangle(s) on the PDF page
                             img_rects = pdf_page.get_image_rects(xref)
                             if img_rects:
                                 img_rect = img_rects[0] # Assuming one rect per image xref
                                 print(f"Found image instance coordinates: {img_rect}")
                                 # Draw blue rectangle on the PDF page
                                 pdf_page.draw_rect(img_rect, color=(0, 0, 1), width=3) # Draw on PDF page, increased width
                                 found_image = True
                                 print("Drew blue rectangle.")
                                 break # Assume we found the right image
                    if not found_image:
                         print(f"Warning: Could not find image instance for highlighting on page {page_num + 1} for path '{cited_path}'.")


            except ValueError:
                print(f"Skipping invalid cited page number: {cited_page_str}")
            except Exception as e:
                print(f"An error occurred while highlighting citation for path '{cited_path}': {e}")

        # Get a new pixmap of the page with the drawings
        highlighted_pix = pdf_page.get_pixmap()

        # Save the modified pixmap to a temporary file
        highlighted_image_path = image_path.replace(".png", "_highlighted.png")
        highlighted_pix.save(highlighted_image_path)

        # Display the highlighted image
        print(f"Displaying highlighted image for page {page_num + 1}:")
        display(Image(filename=highlighted_image_path))

        doc.close() # Close the document
        # highlighted_pix.close() # Removed incorrect close call


    except FileNotFoundError:
        print(f"Error: The page image file '{image_path}' was not found.")
    except Exception as e:
        print(f"An error occurred while processing the page image: {e}")
        # Remove the specific hint as it seems to be misleading
        # if 'Document' in str(e) and 'width' in str(e):
        #      print("Hint: The error 'Document' object has no attribute 'width' suggests an issue accessing width/height from the main PDF document object instead of a specific page or pixmap.")

# Example usage (replace with your actual usage):
# unique_cited_pages = list(set([ref["page"] for ref in cited_references]))
# for page_num_str in unique_cited_pages:
#     try:
#         page_num = int(page_num_str)
#         image_path_for_page = os.path.join("data", f"page_images/page_{page_num - 1:03d}.png")
#         if os.path.exists(image_path_for_page):
#             optimized_highlight_citations_on_page_image(image_path_for_page, cited_references, items)
#         else:
#             print(f"Page image not found for page {page_num} at {image_path_for_page}")
#     except ValueError:
#         print(f"Skipping invalid page number in unique cited pages: {page_num_str}")
#     except Exception as e:
#         print(f"An error occurred while processing unique cited pages: {e}")
